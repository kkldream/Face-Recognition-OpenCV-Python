# %% [markdown]
# ### 環境初始化

# %%
import os
# os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model
from IPython.display import Image
import matplotlib.pyplot as plt
import json
import random
import time
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ### 資料集格式範例

# %% [markdown]
# 檔案標頭
# ```json
# {
#     "file": "1-FemaleNoGlasses-Normal",
#     "size": 419,
#     "fps": 30,
#     "marker_path": "dataset/markers/1-FemaleNoGlasses-Normal.csv",
#     "video_path": "dataset/YawDD/train/1-FemaleNoGlasses-Normal.avi"
# }
# ```
# 標記內容
# ```json
# {
#     "index": 1,
#     "level": "0",
#     "mouth_ear": 0.02305602969572012,
#     "roll": -2.8421378836556643,
#     "yaw": 38.241611421108246,
#     "pitch": -11.410418897867203
# }
# ```

# %% [markdown]
# ### 功能函式

# %% [markdown]
# **自訂功能函式**：map(var, in_min, in_max, out_min, out_max)

# %%
def map(var, in_min, in_max, out_min, out_max):
    var = float(var)
    if var >= in_max:
        return out_max
    if var <= in_min:
        return out_min
    return (var - in_min) * (out_max - out_min) / (in_max - in_min) + out_min

# %% [markdown]
# **讀取資料集且正規化**：readData(file)

# %%
def readDataList(file):
    train_list = []
    with open(file, 'r', encoding='utf-8') as f:
        while True:
            line = f.readline()
            if len(line) == 0: break
            file_json = json.loads(line)
            mlist = []
            for i in range(file_json['size']):
                mline = f.readline()
                mjson = json.loads(mline)
                level = map(mjson['level'], 0, 5, 0, 1)
                mar = map(mjson['mar'], 0, 1, 0, 1)
                ear_l = map(mjson['ear_l'], 0, 1, 0, 1)
                ear_r = map(mjson['ear_r'], 0, 1, 0, 1)
                entropy = map(mjson['entropy'], 0, 30, 0, 1)
                # roll = map(mjson['roll'], -50, 50, -1, 1)
                # yaw = map(mjson['yaw'], -50, 50, -1, 1)
                # pitch = map(mjson['pitch'], -50, 50, -1, 1)
                mlist.append(np.array([
                    level,
                    mar,
                    ear_l,
                    ear_r,
                    entropy
                ]))
            train_list.append(np.array(mlist))
    return np.array(train_list)

# %%
def readDataList(file):
    train_list = []
    with open(file, 'r', encoding='utf-8') as f:
        while True:
            line = f.readline()
            if len(line) == 0: break
            file_json = json.loads(line)
            mlist = []
            for i in range(file_json['size']):
                mline = f.readline()
                mjson = json.loads(mline)
                level = map(mjson['level'], 0, 5, 0, 1)
                mar = map(mjson['mar'], 0, 1, 0, 1)
                ear_l = map(mjson['ear_l'], 0, 1, 0, 1)
                ear_r = map(mjson['ear_r'], 0, 1, 0, 1)
                entropy = map(mjson['entropy'], 0, 30, 0, 1)
                # roll = map(mjson['roll'], -50, 50, -1, 1)
                # yaw = map(mjson['yaw'], -50, 50, -1, 1)
                # pitch = map(mjson['pitch'], -50, 50, -1, 1)
                mlist.append(np.array([
                    level,
                    mar,
                    (ear_l + ear_r) / 2,
                    # ear_l,
                    # ear_r,
                    entropy
                ]))
            train_list.append(np.array(mlist))
    return np.array(train_list)

# %% [markdown]
# **產生訓練資料**：buildTrain(train_list, long=300)

# %%
def buildTrain(train_list, long=300):
  X_train, Y_train = [], []
  for t in train_list:
    train = np.array(t)
    for i in range(train.shape[0]-long):
      X_train.append(train[i:i+long,1:])
      Y_train.append(train[i+long-1][0])
  return np.array(X_train), np.array(Y_train)

# %% [markdown]
# **資料隨機排序**：shuffle(X,Y)

# %%
def shuffle(X,Y):
    np.random.seed(10)
    randomList = np.arange(X.shape[0])
    np.random.shuffle(randomList)
    return X[randomList], Y[randomList]

# %% [markdown]
# **產生驗證資料**：splitData(X, Y, rate)

# %%
def splitData(X, Y, rate):
    X_train = X[int(X.shape[0]*rate):]
    Y_train = Y[int(Y.shape[0]*rate):]
    X_val = X[:int(X.shape[0]*rate)]
    Y_val = Y[:int(Y.shape[0]*rate)]
    return X_train, Y_train, X_val, Y_val

# %% [markdown]
# ### 主程式

# %% [markdown]
# ##### 建立訓練資料

# %%
train_list = readDataList('train_data.txt')
X_train, Y_train = buildTrain(train_list, 600)
X_train, Y_train = shuffle(X_train, Y_train)
X_train, Y_train, X_val, Y_val = splitData(X_train, Y_train, 0.2)
X_val, Y_val, X_test, Y_test = splitData(X_val, Y_val, 0.5)
# Out:
# C:\Users\kk693\AppData\Local\Temp\ipykernel_29456\324845506.py:29: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(train_list)

# %%
print(X_train.shape)
x_train = [None] * 3
x_train[0] = X_train[:, :, 0:1]
x_train[1] = X_train[:, :, 1:2]
x_train[2] = X_train[:, -1:, 2]
print(x_train[0].shape)
print(x_train[1].shape)
print(x_train[2].shape)
# Out:
# (35296, 600, 3)
# (35296, 600, 1)
# (35296, 600, 1)
# (35296, 1)

# %%
print(X_val.shape)
x_val = [None] * 3
x_val[0] = X_val[:, :, 0:1]
x_val[1] = X_val[:, :, 1:2]
x_val[2] = X_val[:, -1:, 2]
print(x_val[0].shape)
print(x_val[1].shape)
print(x_val[2].shape)
# Out:
# (4412, 600, 3)
# (4412, 600, 1)
# (4412, 600, 1)
# (4412, 1)

# %%
print(X_test.shape)
x_test = [None] * 3
x_test[0] = X_test[:, :, 0:1]
x_test[1] = X_test[:, :, 1:2]
x_test[2] = X_test[:, -1:, 2]
print(x_test[0].shape)
print(x_test[1].shape)
print(x_test[2].shape)
# Out:
# (4412, 600, 3)
# (4412, 600, 1)
# (4412, 600, 1)
# (4412, 1)

# %% [markdown]
# **訓練資料圖形化**

# %%
def drawTrain(i, num):
    plt.subplot(210 + i)
    plt.plot(X_train[num,:,0], label='mar')
    plt.plot(X_train[num,:,1], label='ear')
    plt.plot(X_train[num,:,2], label='entropy')
    # plt.plot(X_train[num,:,1], label='ear_l')
    # plt.plot(X_train[num,:,2], label='ear_r')
    # plt.plot(X_train[num,:,3], label='entropy')
    print(f'X_data = [{num},:,0], Y_data = {Y_train[num]}')
    plt.ylim(0, 0.5)
    plt.legend()
    plt.grid(True)
    plt.show()
def getRnd():
    return random.randint(0, X_train.shape[0] - 1)
def draw():
    while True:
        rnd = getRnd()
        if Y_train[rnd] > 0.5:
            drawTrain(1, rnd)
            break
    while True:
        rnd = getRnd()
        if Y_train[rnd] <= 0.5:
            drawTrain(2, rnd)
            break
draw()
# Out:
# X_data = [27470,:,0], Y_data = 1.0
# X_data = [2477,:,0], Y_data = 0.0

# %% [markdown]
# ##### 建立訓練模型

# %%
input_1 = keras.Input(shape=(600, 1), name='input_mar')
hidden_1 = layers.Conv1D(32, kernel_size=3, strides=1, padding='same', activation='relu')(input_1)
hidden_1 = layers.MaxPooling1D(pool_size=3, padding='valid')(hidden_1)
hidden_1 = layers.Flatten()(hidden_1)
output = layers.Dense(1, name='output')(hidden_1)

model = keras.Model(inputs=[input_1], outputs=[output])
params_num = model.count_params()
print(f'params_num = {params_num}')
model.summary()
plot_model(model, show_shapes=True)
# Out:
# params_num = 6529
# Model: "model_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_mar (InputLayer)       [(None, 600, 1)]          0
# _________________________________________________________________
# conv1d_39 (Conv1D)           (None, 600, 32)           128
# _________________________________________________________________
# max_pooling1d_25 (MaxPooling (None, 200, 32)           0
# _________________________________________________________________
# flatten_26 (Flatten)         (None, 6400)              0
# _________________________________________________________________
# output (Dense)               (None, 1)                 6401
# =================================================================
# Total params: 6,529
# Trainable params: 6,529
# Non-trainable params: 0
# _________________________________________________________________

# %%
input_1 = keras.Input(shape=(600, 1), name='input_mar')
hidden_1 = layers.Conv1D(32, kernel_size=3, strides=2, padding='same', activation='relu')(input_1)
hidden_1 = layers.Conv1D(32, kernel_size=3, strides=2, padding='same', activation='relu')(hidden_1)
hidden_1 = layers.MaxPooling1D(pool_size=3, padding='valid')(hidden_1)
hidden_1 = layers.BatchNormalization()(hidden_1)
hidden_1 = layers.Flatten()(hidden_1)
hidden_1 = layers.Dense(32)(hidden_1)
hidden_1 = layers.Dropout(0.2)(hidden_1)
hidden_1 = layers.Dense(32, activation='relu')(hidden_1)

input_2 = keras.Input(shape=(600, 1), name='input_ear')
hidden_2 = layers.Conv1D(32, kernel_size=3, strides=2, padding='same', activation='relu')(input_2)
hidden_2 = layers.Conv1D(32, kernel_size=3, strides=2, padding='same', activation='relu')(hidden_2)
hidden_2 = layers.MaxPooling1D(pool_size=3, padding='valid')(hidden_2)
hidden_2 = layers.BatchNormalization()(hidden_2)
hidden_2 = layers.Flatten()(hidden_2)
hidden_2 = layers.Dense(32)(hidden_2)
hidden_2 = layers.Dropout(0.2)(hidden_2)
hidden_2 = layers.Dense(32, activation='relu')(hidden_2)

input_3 = keras.Input(shape=(1, ), name='input_entropy')
hidden_3 = layers.Dense(32, activation="relu")(input_3)
hidden_3 = layers.BatchNormalization()(hidden_3)
hidden_3 = layers.Dropout(0.2)(hidden_3)
hidden_3 = layers.Dense(32, activation='relu')(hidden_3)

concat = layers.Concatenate(axis=-1)([hidden_1, hidden_2, hidden_3])
concat_h1 = layers.Dense(64)(concat)
concat_h1 = layers.BatchNormalization()(concat_h1)
concat_h1 = layers.ReLU()(concat_h1)
concat_h1 = layers.Dropout(0.2)(concat_h1)
concat_h1 = layers.Dense(32, activation='relu')(concat_h1)
concat_h1 = layers.Dropout(0.2)(concat_h1)
concat_h1 = layers.Dense(32, activation='relu')(concat_h1)
concat_h1 = layers.Dropout(0.2)(concat_h1)
output = layers.Dense(1, name='output')(concat_h1)

model = keras.Model(inputs=[input_1, input_2, input_3], outputs=[output])
params_num = model.count_params()
print(f'params_num = {params_num}')
model.summary()
plot_model(model, show_shapes=True)
# Out:
# params_num = 122177
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_mar (InputLayer)          [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_ear (InputLayer)          [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 32)      128         input_mar[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 32)      128         input_ear[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 32)      3104        conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 32)      3104        conv1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 50, 32)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 50, 32)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 50, 32)       128         max_pooling1d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 50, 32)       128         max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# input_entropy (InputLayer)      [(None, 1)]          0
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1600)         0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1600)         0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 32)           64          input_entropy[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           51232       flatten[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 32)           51232       flatten_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32)           128         dense_4[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32)           0           dense[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32)           0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 32)           1056        dropout[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 32)           1056        dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 32)           1056        dropout_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 96)           0           dense_1[0][0]
#                                                                  dense_3[0][0]
#                                                                  dense_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           6208        concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64)           256         dense_6[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 64)           0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64)           0           re_lu[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 32)           2080        dropout_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32)           0           dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 32)           1056        dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 32)           0           dense_8[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            33          dropout_5[0][0]
# ==================================================================================================
# Total params: 122,177
# Trainable params: 121,857
# Non-trainable params: 320
# __________________________________________________________________________________________________

# %% [markdown]
# ##### 開始訓練

# %%
''' trainParam '''
model_tag = 'Conv2_dense'
optimizer = "adam"
loss = "mse"
batch_size = 256
epochs = 10000
time_tag = time.strftime("%Y_%m_%d-%H_%M_%S", time.localtime())
model_dir = f'{time_tag}-{model_tag}-params_{params_num}-batch_{batch_size}-optimizer_{optimizer}-loss_{loss}'
print(model_dir)
callbacks = list()
model.compile(optimizer="adam", loss="mse")
''' EarlyStopping '''
callbacks.append(
    keras.callbacks.EarlyStopping(monitor="loss", patience=10, verbose=1, mode="auto")
)
''' ModelCheckpoint '''
model_name = 'epoch_{epoch:03d}-val_loss_{val_loss:.3f}.hdf5'
filepath = os.path.join('models', model_dir, model_name)
callbacks.append(
    keras.callbacks.ModelCheckpoint(filepath, monitor='val_loss', verbose=0, save_best_only=False, save_weights_only=False, mode='auto', save_freq='epoch')
)
''' TensorBoard '''
log_dir = os.path.join('models', 'logs', model_dir)
callbacks.append(
    keras.callbacks.TensorBoard(log_dir=log_dir)
)
# Out:
# 2022_04_19-15_54_46-Conv2_dense-params_122177-batch_256-optimizer_adam-loss_mse

# %%
trainHistory = model.fit(
    x_train, Y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_val, Y_val),
    callbacks=callbacks
)
# Out:
# Epoch 1/10000
# 138/138 [==============================] - 8s 19ms/step - loss: 0.0566 - val_loss: 0.0182
# Epoch 2/10000
# 138/138 [==============================] - 2s 16ms/step - loss: 0.0120 - val_loss: 0.0184
# Epoch 3/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0068 - val_loss: 0.0181
# Epoch 4/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0047 - val_loss: 0.0122
# Epoch 5/10000
# 138/138 [==============================] - 2s 15ms/step - loss: 0.0036 - val_loss: 0.0066
# Epoch 6/10000
# 138/138 [==============================] - 2s 15ms/step - loss: 0.0033 - val_loss: 0.0024
# Epoch 7/10000
# 138/138 [==============================] - 2s 16ms/step - loss: 0.0028 - val_loss: 0.0021
# Epoch 8/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0025 - val_loss: 0.0016
# Epoch 9/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 10/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 11/10000
# 138/138 [==============================] - 2s 15ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 12/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0020 - val_loss: 0.0028
# Epoch 13/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0017 - val_loss: 0.0039
# Epoch 14/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 15/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0015 - val_loss: 0.0024
# Epoch 16/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 17/10000
# 138/138 [==============================] - 2s 15ms/step - loss: 0.0015 - val_loss: 0.0026
# Epoch 18/10000
# 138/138 [==============================] - 2s 16ms/step - loss: 0.0014 - val_loss: 0.0037
# Epoch 19/10000
# 138/138 [==============================] - 2s 18ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 20/10000
# 138/138 [==============================] - 2s 15ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 21/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 22/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 23/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 24/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 25/10000
# 138/138 [==============================] - 2s 16ms/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 26/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 27/10000
# 138/138 [==============================] - 2s 15ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 28/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 29/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0011 - val_loss: 0.0027
# Epoch 30/10000
# 138/138 [==============================] - 2s 16ms/step - loss: 0.0012 - val_loss: 0.0025
# Epoch 31/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 32/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0011 - val_loss: 0.0041
# Epoch 33/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 34/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 35/10000
# 138/138 [==============================] - 2s 15ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 36/10000
# 138/138 [==============================] - 2s 15ms/step - loss: 8.6527e-04 - val_loss: 0.0014
# Epoch 37/10000
# 138/138 [==============================] - 2s 16ms/step - loss: 9.4681e-04 - val_loss: 0.0055
# Epoch 38/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 9.6967e-04 - val_loss: 0.0037
# Epoch 39/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 9.2531e-04 - val_loss: 0.0020
# Epoch 40/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 9.3064e-04 - val_loss: 0.0019
# Epoch 41/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 9.4402e-04 - val_loss: 0.0016
# Epoch 42/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 8.4258e-04 - val_loss: 0.0012
# Epoch 43/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 9.2739e-04 - val_loss: 0.0025
# Epoch 44/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 8.7552e-04 - val_loss: 0.0018
# Epoch 45/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 7.9369e-04 - val_loss: 0.0013
# Epoch 46/10000
# 138/138 [==============================] - 2s 15ms/step - loss: 7.8146e-04 - val_loss: 0.0011
# Epoch 47/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 7.9277e-04 - val_loss: 0.0019
# Epoch 48/10000
# 138/138 [==============================] - 2s 15ms/step - loss: 7.8520e-04 - val_loss: 0.0013
# Epoch 49/10000
# 138/138 [==============================] - 2s 15ms/step - loss: 7.1134e-04 - val_loss: 0.0015
# Epoch 50/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 7.6625e-04 - val_loss: 0.0018
# Epoch 51/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 6.9224e-04 - val_loss: 9.7135e-04
# Epoch 52/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 7.5255e-04 - val_loss: 0.0010
# Epoch 53/10000
# 138/138 [==============================] - 2s 15ms/step - loss: 6.5700e-04 - val_loss: 0.0017
# Epoch 54/10000
# 138/138 [==============================] - 2s 15ms/step - loss: 6.7942e-04 - val_loss: 0.0016
# Epoch 55/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 6.9226e-04 - val_loss: 9.4370e-04
# Epoch 56/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 7.3988e-04 - val_loss: 0.0019
# Epoch 57/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 6.7547e-04 - val_loss: 0.0029
# Epoch 58/10000
# 138/138 [==============================] - 2s 15ms/step - loss: 6.9372e-04 - val_loss: 0.0022
# Epoch 59/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 7.0273e-04 - val_loss: 0.0022
# Epoch 60/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 5
10000
# 138/138 [==============================] - 2s 14ms/step - loss: 4.2112e-04 - val_loss: 2.9971e-04
# Epoch 108/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 4.5148e-04 - val_loss: 7.3347e-04
# Epoch 109/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 3.9524e-04 - val_loss: 6.0305e-04
# Epoch 110/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 6.0214e-04 - val_loss: 0.0078
# Epoch 111/10000
# 138/138 [==============================] - 2s 15ms/step - loss: 4.9292e-04 - val_loss: 5.2238e-04
# Epoch 112/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 3.9599e-04 - val_loss: 2.4886e-04
# Epoch 113/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 4.1383e-04 - val_loss: 4.8819e-04
# Epoch 114/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 4.1649e-04 - val_loss: 4.1171e-04
# Epoch 115/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 3.7728e-04 - val_loss: 4.3826e-04
# Epoch 116/10000
# 138/138 [==============================] - 2s 16ms/step - loss: 4.0298e-04 - val_loss: 3.2928e-04
# Epoch 117/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 4.0508e-04 - val_loss: 3.4308e-04
# Epoch 118/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 4.9221e-04 - val_loss: 4.0771e-04
# Epoch 119/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 3.8357e-04 - val_loss: 4.6511e-04
# Epoch 120/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 3.7910e-04 - val_loss: 5.1488e-04
# Epoch 121/10000
# 138/138 [==============================] - 2s 15ms/step - loss: 4.0641e-04 - val_loss: 3.4307e-04
# Epoch 122/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 3.6668e-04 - val_loss: 3.2211e-04
# Epoch 123/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 3.5029e-04 - val_loss: 3.3634e-04
# Epoch 124/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 4.4620e-04 - val_loss: 4.2532e-04
# Epoch 125/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 4.1234e-04 - val_loss: 4.2997e-04
# Epoch 126/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 4.0893e-04 - val_loss: 3.2392e-04
# Epoch 127/10000
# 138/138 [==============================] - 2s 15ms/step - loss: 4.2755e-04 - val_loss: 2.7681e-04
# Epoch 128/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 4.0453e-04 - val_loss: 3.1099e-04
# Epoch 129/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 3.3927e-04 - val_loss: 3.5435e-04
# Epoch 130/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 3.9800e-04 - val_loss: 4.6960e-04
# Epoch 131/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 3.6806e-04 - val_loss: 3.4179e-04
# Epoch 132/10000
# 138/138 [==============================] - 2s 15ms/step - loss: 4.1064e-04 - val_loss: 3.5397e-04
# Epoch 133/10000
# 138/138 [==============================] - 2s 15ms/step - loss: 4.4590e-04 - val_loss: 6.4382e-04
# Epoch 134/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 3.7971e-04 - val_loss: 2.2261e-04
# Epoch 135/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 4.2452e-04 - val_loss: 3.3637e-04
# Epoch 136/10000
# 138/138 [==============================] - 2s 16ms/step - loss: 5.1459e-04 - val_loss: 2.4239e-04
# Epoch 137/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 3.7878e-04 - val_loss: 4.4121e-04
# Epoch 138/10000
# 138/138 [==============================] - 2s 16ms/step - loss: 3.9220e-04 - val_loss: 3.4630e-04
# Epoch 139/10000
# 138/138 [==============================] - 2s 14ms/step - loss: 3.7913e-04 - val_loss: 3.7323e-04
# Epoch 00139: early stopping

# %% [markdown]
# **繪製Loss線**

# %%
plt.plot(trainHistory.history['loss'], color='r', label='loss')
plt.plot(trainHistory.history['val_loss'], color='b', label='val_loss')
plt.legend()
plt.show()

# %% [markdown]
# ### 匯出模型

# %% [markdown]
# # 測試模型

# %%
predicted = model.predict(x_test)

# %%
predicted[predicted<0] = 0

# %%
r = random.randint(0, len(Y_test))
plt.figure(dpi=200)
plt.plot(Y_test[r:r+300], color='r', label='Y_test')
plt.plot(predicted[r:r+300], color='b', label='Predicted')
plt.legend()
plt.ylim(0, 1.1)
plt.show()

# %%
for r in range(0, len(Y_test), 50):
    plt.figure(dpi=300)
    plt.plot(Y_test[r:r+50], color='r', label='Y_test')
    plt.plot(predicted[r:r+50], color='b', label='Predicted')
    plt.legend()
    plt.show()
