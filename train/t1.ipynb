# %% [markdown]
# # 環境初始化

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
os.chdir("work/Fatigue-Driving-Detection")
# !pwd
# Out:
# /home/jovyan/work/Fatigue-Driving-Detection

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import load_model
from IPython.display import Image
import matplotlib.pyplot as plt
import json
import random
import time
import utils
import pandas as pd
# %matplotlib inline

# %%
physical_gpus = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_gpus[0], True)

# %% [markdown]
# # 資料集格式範例

# %% [markdown]
# ```json
# # 檔案標頭
# {
#     "file": "1-FemaleNoGlasses-Normal",
#     "size": 419,
#     "fps": 30,
#     "marker_path": "dataset/markers/1-FemaleNoGlasses-Normal.csv",
#   "video_path": "dataset/YawDD/train/1-FemaleNoGlasses-Normal.avi"
# }
#
# # 標記內容
# {
#     "index": 1,
#     "mode": "Normal",
#     "level": "0",
#     "mar": 0.025642701314247437,
#     "ear_l": 0.2986032435056242,
#     "ear_r": 0.3937485488274893,
#     "entropy": -16089.327941184894,
#     "roll": -2,
#     "yaw": 37,
#     "pitch": -12
# }
# ```

# %% [markdown]
# # 功能函式

# %%
def norm_max_min(var, in_min, in_max, out_min=0, out_max=1):
    var = float(var)
    if var >= in_max:
        return out_max
    if var <= in_min:
        return out_min
    return (var - in_min) * (out_max - out_min) / (in_max - in_min) + out_min

# %%
def readDataList(file):
    data_list = []
    with open(file, 'r', encoding='utf-8') as f:
        while True:
            line = f.readline()
            if len(line) == 0: break
            file_json = json.loads(line)
            mlist = []
            for _ in range(file_json['size']):
                mjson = json.loads(f.readline())
                mode = (mjson['mode'] == 'Yawning')
                mar = norm_max_min(mjson['mar'], 0, 1)
                ear_l = norm_max_min(mjson['ear_l'], 0, 1)
                ear_r = norm_max_min(mjson['ear_r'], 0, 1)
                entropy = norm_max_min(mjson['entropy'], 0, 30)
                # roll = norm_max_min(mjson['roll'], -50, 50)
                yaw = norm_max_min(mjson['yaw'], -50, 50)
                # pitch = norm_max_min(mjson['pitch'], -50, 50)
                if yaw >= 0: ear = ear_r
                else: ear = ear_l
                mlist.append(np.array([
                    mode,
                    mar,
                    ear,
                    entropy
                ]))
            data_list.append(np.array(mlist))
    return np.array(data_list)

# %%
def buildTrain(data_list, long=300):
  x_data, y_data = [], []
  for t in data_list:
    train = np.array(t)
    for i in range(train.shape[0]-long):
      x_data.append(train[i:i+long,1:])
      y_data.append(train[i+long-1][0])
  return np.array(x_data), np.array(y_data)

# %%
random_seed = 0
def shuffle(x_data, y_data):
    np.random.seed(random_seed)
    randomList = np.arange(x_data.shape[0])
    np.random.shuffle(randomList)
    return x_data[randomList], y_data[randomList]

# %%
def splitData(data_0, data_1, test_rate):
    data_0_train = data_0[int(data_0.shape[0] * test_rate):]
    data_0_test = data_0[:int(data_0.shape[0] * test_rate)]
    data_1_train = data_1[int(data_1.shape[0] * test_rate):]
    data_1_test = data_1[:int(data_1.shape[0] * test_rate)]
    return data_0_train, data_1_train, data_0_test, data_1_test

# %% [markdown]
# # 主程式

# %% [markdown]
# ##### 建立訓練資料

# %%
train_list = readDataList('train_data.txt')
X_trains, Y_train = buildTrain(train_list, 300)
print(X_trains.shape, Y_train.shape)
X_trains, Y_train = shuffle(X_trains, Y_train)
X_trains, Y_train, X_tests, Y_test = splitData(X_trains, Y_train, 0.4)
X_tests, Y_test, X_vals, Y_val = splitData(X_tests, Y_test, 0.5)
# Out:
# <ipython-input-5-49569e82303d>:28: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(data_list)
# (127739, 300, 3) (127739,)

# %%
def seg_data(data):
    seg = [None] * 2
    seg[0] = data[:, :, 0:2] # mar list
    seg[1] = np.average(data[:, :, 2], 1) # entropy
    print(f'{data.shape} -> {seg[0].shape} + {seg[1].shape}')
    return seg

X_train = seg_data(X_trains)
X_val = seg_data(X_vals)
X_test = seg_data(X_tests)
# Out:
# (76644, 300, 3) -> (76644, 300, 2) + (76644,)
# (25547, 300, 3) -> (25547, 300, 2) + (25547,)
# (25548, 300, 3) -> (25548, 300, 2) + (25548,)

# %% [markdown]
# **訓練資料圖形化**

# %%
def drawTrain(sub, num):
    plt.subplot(210 + sub)
    plt.plot(X_trains[num,:,0], label='mar')
    plt.plot(X_trains[num,:,1], label='ear')
    plt.plot(X_trains[num,:,2], label='entropy')
    print(f'X_data = [{num},:,:], Y_data = {Y_train[num]}')
    plt.ylim(0, 1)
    plt.legend()
    plt.xticks(np.linspace(0, 300, 11), [f'{int(x)}s' for x in (np.linspace(0,300,11) / 30)])
    plt.yticks(np.linspace(0, 1, 5), [f'{int(x * 100)}%' for x in (np.linspace(0, 1, 5))])
    plt.grid(True)
    plt.show()

def getRnd():
    return random.randint(0, X_trains.shape[0] - 1)

def draw():
    while True:
        rnd = getRnd()
        if Y_train[rnd] > 0.5:
            drawTrain(1, rnd)
            break
    while True:
        rnd = getRnd()
        if Y_train[rnd] <= 0.5:
            drawTrain(2, rnd)
            break
draw()
# Out:
# X_data = [938,:,:], Y_data = 1.0
# X_data = [40983,:,:], Y_data = 0.0

# %% [markdown]
# ##### 建立訓練模型

# %%
input_1 = keras.Input(shape=(300, 2))
hidden_1 = layers.Conv1D(64, kernel_size=3, strides=2, padding='same', activation="relu", kernel_initializer="he_normal")(input_1)
# hidden_1 = layers.Conv1D(64, kernel_size=2, strides=1, padding='same', activation="relu", kernel_initializer="he_normal")(hidden_1)
hidden_1 = layers.MaxPooling1D(pool_size=3, padding='valid')(hidden_1)
# hidden_1 = layers.BatchNormalization()(hidden_1)
# hidden_1 = layers.Flatten()(hidden_1)
# hidden_1 = layers.LSTM(64, return_sequences=True)(hidden_1)
# hidden_1 = layers.Dropout(0.2)(hidden_1)
hidden_1 = layers.LSTM(64)(hidden_1)
# hidden_1 = layers.Dense(64, activation="relu", kernel_initializer="he_normal")(hidden_1)
# hidden_1 = layers.Dense(64, activation="relu", kernel_initializer="he_normal")(hidden_1)
hidden_1 = layers.BatchNormalization()(hidden_1)

input_2 = keras.Input(shape=(1, ))

concat = layers.Concatenate(axis=-1)([hidden_1, input_2])
concat_h1 = layers.Dense(64, activation="relu", kernel_initializer="he_normal")(concat)
# concat_h1 = layers.Dropout(0.2)(concat_h1)
# concat_h1 = layers.Dense(32, activation="relu", kernel_initializer="he_normal")(concat_h1)
output = layers.Dense(1, activation="sigmoid")(concat_h1)

model = keras.Model(inputs=[input_1, input_2], outputs=[output])
params_num = model.count_params()
print(f'params_num = {params_num}')
model.summary()
plot_model(model, show_shapes=True)
# Out:
# params_num = 38017
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 300, 2)]     0
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 64)      448         input_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 50, 64)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 64)           33024       max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64)           256         lstm_1[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 65)           0           batch_normalization_1[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           4224        concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 38,017
# Trainable params: 37,889
# Non-trainable params: 128
# __________________________________________________________________________________________________

# %% [markdown]
# ##### 開始訓練

# %%
''' trainParam '''
save_models = 'models'
model_tag = 'new'
optimizer = "adam"
loss = "BinaryCrossentropy"
batch_size = 2048
epochs = 10000
time_tag = time.strftime("%Y_%m_%d-%H_%M_%S", time.localtime())
model_dir = f'{time_tag}-{model_tag}-params_{params_num}-batch_{batch_size}'
print(os.path.join(save_models, model_dir))
callbacks = list()
model.compile(optimizer=optimizer, loss=loss, metrics=['BinaryAccuracy'])
''' EarlyStopping '''
callbacks.append(
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=10, verbose=1, mode="auto")
)
''' ModelCheckpoint '''
model_name = 'epoch_{epoch:03d}-val_loss_{val_loss:.3f}.h5'
all_filepath = os.path.join(save_models, model_dir, 'all_models', model_name)
callbacks.append(
    keras.callbacks.ModelCheckpoint(all_filepath, monitor='val_loss', verbose=0, save_best_only=False, save_weights_only=False, mode='auto', save_freq='epoch')
)
best_filepath = os.path.join(save_models, model_dir, 'model.h5')
callbacks.append(
    keras.callbacks.ModelCheckpoint(best_filepath, monitor='val_loss', verbose=0, save_best_only=True, save_weights_only=False, mode='auto', save_freq='epoch')
)
''' TensorBoard '''
log_dir = os.path.join(save_models, 'logs', model_dir)
callbacks.append(
    keras.callbacks.TensorBoard(log_dir=log_dir)
)
# Out:
# models/2022_06_09-09_51_16-new-params_38017-batch_2048

# %%
trainHistory = model.fit(
    X_train, Y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, Y_val),
    callbacks=callbacks
)
# Out:
# Epoch 1/10000
# 38/38 [==============================] - 21s 260ms/step - loss: 0.6081 - binary_accuracy: 0.6639 - val_loss: 0.5109 - val_binary_accuracy: 0.7922
# Epoch 2/10000
# 38/38 [==============================] - 1s 25ms/step - loss: 0.2422 - binary_accuracy: 0.9151 - val_loss: 0.4419 - val_binary_accuracy: 0.8913
# Epoch 3/10000
# 38/38 [==============================] - 1s 21ms/step - loss: 0.1925 - binary_accuracy: 0.9329 - val_loss: 0.3161 - val_binary_accuracy: 0.9050
# Epoch 4/10000
# 38/38 [==============================] - 1s 21ms/step - loss: 0.1710 - binary_accuracy: 0.9400 - val_loss: 0.2997 - val_binary_accuracy: 0.9263
# Epoch 5/10000
# 38/38 [==============================] - 1s 21ms/step - loss: 0.1532 - binary_accuracy: 0.9463 - val_loss: 0.2314 - val_binary_accuracy: 0.9323
# Epoch 6/10000
# 38/38 [==============================] - 1s 21ms/step - loss: 0.1512 - binary_accuracy: 0.9469 - val_loss: 0.2923 - val_binary_accuracy: 0.9474
# Epoch 7/10000
# 38/38 [==============================] - 1s 21ms/step - loss: 0.1403 - binary_accuracy: 0.9508 - val_loss: 0.1944 - val_binary_accuracy: 0.9368
# Epoch 8/10000
# 38/38 [==============================] - 1s 21ms/step - loss: 0.1361 - binary_accuracy: 0.9518 - val_loss: 0.3274 - val_binary_accuracy: 0.8533
# Epoch 9/10000
# 38/38 [==============================] - 1s 21ms/step - loss: 0.1326 - binary_accuracy: 0.9532 - val_loss: 0.1765 - val_binary_accuracy: 0.9524
# Epoch 10/10000
# 38/38 [==============================] - 1s 24ms/step - loss: 0.1267 - binary_accuracy: 0.9556 - val_loss: 0.1909 - val_binary_accuracy: 0.9529
# Epoch 11/10000
# 38/38 [==============================] - 1s 22ms/step - loss: 0.1138 - binary_accuracy: 0.9595 - val_loss: 0.2139 - val_binary_accuracy: 0.9212
# Epoch 12/10000
# 38/38 [==============================] - 1s 21ms/step - loss: 0.1118 - binary_accuracy: 0.9605 - val_loss: 0.1437 - val_binary_accuracy: 0.9490
# Epoch 13/10000
# 38/38 [==============================] - 1s 22ms/step - loss: 0.1135 - binary_accuracy: 0.9606 - val_loss: 0.1464 - val_binary_accuracy: 0.9490
# Epoch 14/10000
# 38/38 [==============================] - 1s 22ms/step - loss: 0.1108 - binary_accuracy: 0.9612 - val_loss: 0.1078 - val_binary_accuracy: 0.9649
# Epoch 15/10000
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0985 - binary_accuracy: 0.9655 - val_loss: 0.2360 - val_binary_accuracy: 0.9261
# Epoch 16/10000
# 38/38 [==============================] - 1s 22ms/step - loss: 0.1129 - binary_accuracy: 0.9605 - val_loss: 0.1198 - val_binary_accuracy: 0.9606
# Epoch 17/10000
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0947 - binary_accuracy: 0.9671 - val_loss: 0.1681 - val_binary_accuracy: 0.9378
# Epoch 18/10000
# 38/38 [==============================] - 1s 22ms/step - loss: 0.0924 - binary_accuracy: 0.9688 - val_loss: 0.4431 - val_binary_accuracy: 0.8583
# Epoch 19/10000
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0976 - binary_accuracy: 0.9652 - val_loss: 0.9971 - val_binary_accuracy: 0.6329
# Epoch 20/10000
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0945 - binary_accuracy: 0.9669 - val_loss: 0.1196 - val_binary_accuracy: 0.9590
# Epoch 21/10000
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0785 - binary_accuracy: 0.9731 - val_loss: 0.5870 - val_binary_accuracy: 0.7687
# Epoch 22/10000
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0901 - binary_accuracy: 0.9682 - val_loss: 0.1711 - val_binary_accuracy: 0.9490
# Epoch 23/10000
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0839 - binary_accuracy: 0.9712 - val_loss: 0.1254 - val_binary_accuracy: 0.9504
# Epoch 24/10000
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0743 - binary_accuracy: 0.9765 - val_loss: 0.0919 - val_binary_accuracy: 0.9702
# Epoch 25/10000
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0793 - binary_accuracy: 0.9726 - val_loss: 0.1442 - val_binary_accuracy: 0.9499
# Epoch 26/10000
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0734 - binary_accuracy: 0.9754 - val_loss: 0.0853 - val_binary_accuracy: 0.9715
# Epoch 27/10000
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0699 - binary_accuracy: 0.9767 - val_loss: 0.3141 - val_binary_accuracy: 0.9034
# Epoch 28/10000
# 38/38 [==============================] - 1s 22ms/step - loss: 0.0664 - binary_accuracy: 0.9775 - val_loss: 0.1012 - val_binary_accuracy: 0.9669
# Epoch 29/10000
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0705 - binary_accuracy: 0.9762 - val_loss: 0.1592 - val_binary_accuracy: 0.9405
# Epoch 30/10000
# 38/38 [==============================] - 1s 22ms/step - loss: 0.0622 - binary_accuracy: 0.9797 - val_loss: 0.0648 - val_binary_accuracy: 0.9793
# Epoch 31/10000
# 38/38 [==============================] - 1s 22ms/step - loss: 0.0579 - binary_accuracy: 0.9813 - val_loss: 0.0572 - val_binary_accuracy: 0.9806
# Epoch 32/10000
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0564 - binary_accuracy: 0.9814 - val_loss: 0.1148 - val_binary_accuracy: 0.9588
# Epoch 33/10000
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0533 - binary_accuracy: 0.9828 - val_loss: 0.0676 - val_binary_accuracy: 0.9782
# Epoch 34/10000
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0616 - binary_accuracy: 0.9793 - val_loss: 0.1013 - val_binary_accuracy: 0.9642
# Epoch 35/10000
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0528 - binary_accuracy: 0.9824 - val_loss: 0.1720 - val_binary_accuracy: 0.9199
# Epoch 36/10000
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0656 - binary_accuracy: 0.9787 - val_loss: 0.0896 - val_binary_accuracy: 0.9669
# Epoch 37/10000
# 38/38 [==============================] - 1s 22ms/step - loss: 0.0537 - binary_accuracy: 0.9828 - val_loss: 0.0634 - val_binary_accuracy: 0.9782
# Epoch 38/10000
# 38/38 [==============================] - 1s 22ms/step - loss: 0.0462 - binary_accuracy: 0.9854 - val_loss: 0.0504 - val_binary_accuracy: 0.9828
# Epoch 39/10000
# 38/38 [==============================] - 1s 22ms/step - loss: 0.0576 - binary_accuracy: 0.9814 - val_loss: 0.2211 - val_binary_accuracy: 0.9407
# Epoch 40/10000
# 38/38 [==============================] - 1s 22ms/step - loss: 0.0523 - binary_accuracy: 0.9834 - val_loss: 0.0739 - val_binary_accuracy: 0.9743
# Epoch 41/10000
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0449 - binary_accuracy: 0.9862 - val_loss: 0.0587 - val_binary_accuracy: 0.9829
# Epoch 42/10000
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0452 - binary_accuracy: 0.9859 - val_loss: 0.0413 - val_binary_accuracy: 0.9864
# Epoch 43/10000
# 38/38 [==============================] - 1s 22ms/step - loss: 0.0394 - binary_accuracy: 0.9877 - val_loss: 0.0461 - val_binary_accuracy: 0.9849
# Epoch 44/10000
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0421 - binary_accuracy: 0.9868 - val_loss: 0.0622 - val_binary_accuracy: 0.9787
# Epoch 45/10000
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0372 - binary_accuracy: 0.9884 - val_loss: 0.2588 - val_binary_accuracy: 0.9323
# Epoch 46/10000
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0410 - binary_accuracy: 0.9870 - val_loss: 0.0532 - val_binary_accuracy: 0.9818
# Epoch 47/10000
# 38/38 [==============================] - 1s 22ms/step - loss: 0.0334 - binary_accuracy: 0.9894 - val_loss: 0.3273 - val_binary_accuracy: 0.8599
# Epoch 48/10000
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0375 - binary_accuracy: 0.9879 - val_loss: 0.0430 - val_binary_accuracy: 0.9863
# Epoch 49/10000
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0336 - binary_accuracy: 0.9894 - val_loss: 0.1027 - val_binary_accuracy: 0.9569
# Epoch 50/10000
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0297 - binary_accuracy: 0.9906 - val_loss: 0.0713 - val_binary_accuracy: 0.9704
# Epoch 51/10000
# 38/38 [==============================] - 1s 22ms/step - loss: 0.0317 - binary_accuracy: 0.9890 - val_loss: 0.6716 - val_binary_accuracy: 0.8000
# Epoch 52/10000
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0329 - binary_accuracy: 0.9887 - val_loss: 0.4669 - val_binary_accuracy: 0.8319
# Epoch 00052: early stopping

# %%
best_model_epoch = trainHistory.history['loss'].index(min(trainHistory.history['loss'])) + 1
with open(os.path.join(save_models, model_dir, 'READMD.md'), 'w', encoding='utf-8') as file:
    file.write('訓練結果：\n')
    file.write(f'\t{trainHistory.history.keys()}\n')
    file.write(f'\tbest_model_epoch = {best_model_epoch}\n')

# %% [markdown]
# **繪製Loss線**

# %%
def draw_history(key):
    filename = f'{model_dir}-history_{key}.jpg'
    path = os.path.join(save_models, model_dir, filename)
    plt.plot(trainHistory.history[key], color='r', label=key)
    plt.plot(trainHistory.history[f'val_{key}'], color='b', label=f'val_{key}')
    plt.legend()
    print(filename)
    plt.savefig(path)
    plt.show()

draw_history('loss')
draw_history('binary_accuracy')
# Out:
# 2022_06_09-09_51_16-new-params_38017-batch_2048-history_loss.jpg
# 2022_06_09-09_51_16-new-params_38017-batch_2048-history_binary_accuracy.jpg

# %% [markdown]
# ### 匯出模型

# %% [markdown]
# # 測試模型

# %%
best_model = load_model(os.path.join(save_models, model_dir, 'model.h5'))

# %%
best_model.evaluate(X_test, Y_test)
# Out:
# 799/799 [==============================] - 5s 5ms/step - loss: 0.0394 - binary_accuracy: 0.9874
# [0.03944145143032074, 0.9873571395874023]

# %%
predicted = best_model.predict(X_test)
predicts_classes = predicted > 0.5

# %%
utils.plot_confusion_matrix(Y_test, predicts_classes, 2, dpi=100)
